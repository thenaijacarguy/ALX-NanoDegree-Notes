# %%
import pandas as pd

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
import numpy as np

# %%
red = np.repeat('red', 1599)

# %%
white = np.repeat('white', 4898)

# %%
red_wine['color'] = red

# %%
white_wine['color'] = white

# %%
wine = red_wine.append(white_wine)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.to_csv('wine.csv', index=False)

# %%
wine.rename(columns = {'alcohol level':'alcohol'}, inplace=True)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
wine.plot(kind='scatter', x='quality', y='volatile acidity')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
wine.plot(kind='scatter', x='quality', y='residual sugar')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
wine.plot(kind='scatter', x='quality', y='pH')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
wine.plot(kind='scatter', x='quality', y='alcohol')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# ...

# %%
wine.groupby(['quality', 'color'], as_index=False).mean()
# Out:
#     quality  color  fixed acidity  volatile acidity  citric acid  \
# 0         3    red       8.360000          0.884500     0.171000
# 1         3  white       7.600000          0.333250     0.336000
# 2         4    red       7.779245          0.693962     0.174151
# 3         4  white       7.129448          0.381227     0.304233
# 4         5    red       8.167254          0.577041     0.243686
# 5         5  white       6.933974          0.302011     0.337653
# 6         6    red       8.347179          0.497484     0.273824
# 7         6  white       6.837671          0.260564     0.338025
# 8         7    red       8.872362          0.403920     0.375176
# 9         7  white       6.734716          0.262767     0.325625
# 10        8    red       8.566667          0.423333     0.391111
# 11        8  white       6.657143          0.277400     0.326514
# 12        9  white       7.420000          0.298000     0.386000
#
# ...

# %%
wine.groupby('quality').count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   30                30           30              30
# 4                  216               216          216             216
# 5                 2138              2138         2138            2138
# 6                 2836              2836         2836            2836
# 7                 1079              1079         1079            1079
# 8                  193               193          193             193
# 9                    5                 5            5               5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3               30                   30                    30       30    30
# 4              216                  216                   216      216   216
# 5             2138                 2138                  2138     2138  2138
# 6             2836                 2836                  2836     2836  2836
# ...

# %%
wine.groupby('color')['quality'].mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
wine.groupby('pH')['quality'].max()
# Out:
# pH
# 2.72    6
# 2.74    6
# 2.77    6
# 2.79    5
# 2.80    6
#        ..
# 3.81    6
# 3.82    7
# 3.85    6
# 3.90    6
# 4.01    6
# Name: quality, Length: 108, dtype: int64

# %%
wine.pH.describe()
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
bin_level = [2.72, 3.12, 3.21, 3.32, 4.01]

# %%
bin_label = ['high', 'mod_high', 'medium', 'low']

# %%
wine['acidity_level'] = pd.cut(wine['pH'], bin_level, labels=bin_label)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.groupby('acidity_level').mean().quality
# Out:
# acidity_level
# high        5.793159
# mod_high    5.772330
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
wine.to_csv('wine.csv', index=False)

# %%
wine[wine['color'] =='red'].head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_level
# 0      9.4        5   red           low
# ...

# %%
wine.query('color =="white"').head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color acidity_level
# 0      8.8        6  white          high
# ...

# %%
wine.query('acidity_level=="medium"').head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2             7.8              0.76         0.04             2.3      0.092
# 6             7.9              0.60         0.06             1.6      0.069
# 10            6.7              0.58         0.08             1.8      0.097
# 13            7.8              0.61         0.29             1.6      0.114
# 16            8.5              0.28         0.56             1.8      0.092
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 16                 35.0                 103.0   0.9969  3.30       0.75
#
#     alcohol  quality color acidity_level
# ...

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_level
# 0      9.4        5   red           low
# ...

# %%
wine.query('alcohol > 10.3').quality.mean()
# Out:
# 6.161773891317926

# %%
wine.alcohol.median()
# Out:
# 10.3

# %%
wine.query('alcohol < 10.3').quality.mean()
# Out:
# 5.475920679886686

# %%
wine.rename(columns = {'residual sugar': 'residual_sugar'}, inplace=True)

# %%
wine.residual_sugar.median()
# Out:
# 3.0

# %%
wine.query('residual_sugar >3.0').quality.mean()
# Out:
# 5.829306071871128

# %%
wine.query('residual_sugar <3.0').quality.mean()
# Out:
# 5.808800743724822

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
wine.groupby('color').quality.mean().plot(kind='pie', title='Average Wine quality by color', colors=('red', 'yellow'))
# Out:
# <AxesSubplot:title={'center':'Average Wine quality by color'}, ylabel='quality'>

# %%
counts = wine.groupby(['quality', 'color']).count()
counts
# Out:
#                fixed acidity  volatile acidity  citric acid  residual_sugar  \
# quality color
# 3       red               10                10           10              10
#         white             20                20           20              20
# 4       red               53                53           53              53
#         white            163               163          163             163
# 5       red              681               681          681             681
#         white           1457              1457         1457            1457
# 6       red              638               638          638             638
#         white           2198              2198         2198            2198
# 7       red              199               199          199             199
#         white            880               880          880             880
# 8       red               18                18           18              18
# ...

# %%
totals = wine.groupby('color').count()['pH']
totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
colors = ['red', 'white']

# %%
proportions = counts / totals

# %%
proportions.plot(kind='bar', title='Proportion by Wine Color and Quality', color=colors, alpha=.7);
plt.xlabel('Quality and Color', fontsize=18)
plt.ylabel('Proportion', fontsize=18)
# Out:
# Text(0, 0.5, 'Proportion')

# %%
plt.bar([1, 2, 3], [224, 620, 425]);

# %%
plt.bar([1, 2, 3], [224, 620, 425])

# specify x coordinates of tick labels and their labels
plt.xticks([1, 2, 3], ['a', 'b', 'c']);

# %%
plt.bar([1, 2, 3], [224, 620, 425], tick_label=['a', 'b', 'c'])
plt.title('Some Title')
plt.xlabel('Some X Label')
plt.ylabel('Some Y Label');

# %%
median = wine['alcohol'].median()
low = wine.query('alcohol < {}'.format(median))
high = wine.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
low = wine.query('alcohol < {}'.format(median)).quality.mean()

# %%
high = wine.query('alcohol >= {}'.format(median)).quality.mean()

# %%
locations = [1, 2]
heights = [low, high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
median = wine.residual_sugar.median()
median
# Out:
# 3.0

# %%
high = wine.query('residual_sugar > {}'.format(median)).quality.mean()
high
# Out:
# 5.829306071871128

# %%
low = wine.query('residual_sugar < {}'.format(median)).quality.mean()
low
# Out:
# 5.808800743724822

# %%
x = [1,2]
y = [low, high]
tick = ['low','high']
plt.bar(x,y, tick_label=tick)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
acidity_rating = wine.groupby('acidity_level').quality.mean()
acidity_rating
# Out:
# acidity_level
# high        5.793159
# mod_high    5.772330
# medium      5.850832
# low         5.859593
# Name: quality, dtype: float64

# %%
location = [1,2,3,4]
plt.bar(location ,acidity_rating, tick_label=('high','mod_high','medium','low'))
plt.title('Ratings by acidity level')
plt.xlabel('Acidity level')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %%
plt.plot(location, acidity_rating)
plt.title('Ratings by acidity level')
plt.xlabel('Acidity level')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')
